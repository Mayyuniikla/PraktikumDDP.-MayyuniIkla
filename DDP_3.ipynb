# %%
Nama="Mayyuni Ikla Azzahra"
NIM="0110124119"
Kelas="SI07"
No_telp="088292040647"
Alamat="kp.Duren baru Rt03/Rw05, Susukan,Bojonggede, Bogor"
print("Nama mahasiswa : ", Nama)
print("NIM mahasiswa : ", NIM)
print ("Kelas/rombel : ", Kelas)
print ("No telp. : ", No_telp)
print ("Alamat : ",Alamat)
# Out:
# Nama mahasiswa :  Mayyuni Ikla Azzahra
# NIM mahasiswa :  0110124119
# Kelas/rombel :  SI07
# No telp. :  088292040647
# Alamat :  kp.Duren baru Rt03/Rw05, Susukan,Bojonggede, Bogor

# %%
Nama="Rahmawati Ibrahim"
NIM="0110124136"
Kelas="SI07"
No_telp="081384930103"
Alamat="Jl.Kartini VIII dalam, No:19,Jakarta Pusat"
print("Nama mahasiswa : ", Nama)
print("NIM mahasiswa : ", NIM)
print ("Kelas/rombel : ", Kelas)
print ("No telp. : ", No_telp)
print ("Alamat : ",Alamat)
# Out:
# Nama mahasiswa :  Rahmawati Ibrahim
# NIM mahasiswa :  0110124136
# Kelas/rombel :  SI07
# No telp. :  081384930103
# Alamat :  Jl.Kartini VIII dalam, No:19,Jakarta Pusat

# %%
#input
tb=int(input("Masukkan Tinggi Badan:"))

#proses
bbIdeal = (tb-100)-((tb-100)*0.1)

#output
print ("Berat badan ideal dengan tinggi badan",tb,"adalah",bbIdeal, "kg")
# Out:
# Masukkan Tinggi Badan:163
# Berat badan ideal dengan tinggi badan 163 adalah 56.7 kg

# %%
#input
celcius= 90
#proses
fahrenheit = (celcius*9/5)+32
#output
print(celcius, "derajat celcius setara dengan", fahrenheit, "derajat fahrenheit")
# Out:
# 90 derajat celcius setara dengan 194.0 derajat fahrenheit

# %%
#input
jariJari, tinggi, phi, kelilingTabung, luasTabung

# %%
#Mencari luas permukaan tabung
# Input
r = 7
t= 10

# proses
luas_permukaan = 2 * 3.14 * r * (r + t)

#Hasil
print("Luas Permukaan Tabung : %.2f"%luas_permukaan)
# Out:
# Luas Permukaan Tabung : 747.32

# %%
#Mencari keliling tabung
#input
jari_jari = 7
luas = 10
phi = 3.14

#proses
keliling = 2 * phi * jari_jari

# hasil
print("Keliling lingkaran alas tabung:", keliling)
# Out:
# Keliling lingkaran alas tabung: 43.96
